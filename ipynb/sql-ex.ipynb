# %%
import psycopg2 as pg2

import pandas as pd

import psycopg2
conn = pg2.connect(host='this_postgres', user='postgres',database='postgres')

conn.autocommit = True

cur = conn.cursor()

def select(sql):
    try:
        df = pd.read_sql(sql,conn)
        return df
    except Exception as e:
        print(e)
    return None

def drop(table):
    try:
        cur.execute(f'drop table if exists {table}')
        print(f'table {table} dropped')
    except Exception as e:
        print(e)
    return None

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
sql = '''select * from printer t'''

# %%
df = select(sql)

# %%
df
# Out:
#    code model color    type  price
# 0     1  1276     n   Laser  400.0
# 1     2  1433     y     Jet  270.0
# 2     3  1434     y     Jet  290.0
# 3     4  1401     n  Matrix  150.0
# 4     5  1408     n  Matrix  270.0
# 5     6  1288     n   Laser  400.0

# %%
sql = '''SELECT * FROM pg_catalog.pg_tables'''

# %%
select(sql)
# Out:
#             schemaname                tablename tableowner tablespace  \
# 0               public                passenger   postgres       None
# 1               public             pass_in_trip   postgres       None
# 2               public                     trip   postgres       None
# 3               public                  company   postgres       None
# 4               public                  product   postgres       None
# 5               public                   laptop   postgres       None
# 6               public                       pc   postgres       None
# 7               public                  printer   postgres       None
# 8               public                   income   postgres       None
# 9               public                  outcome   postgres       None
# 10              public                 income_o   postgres       None
# 11              public                outcome_o   postgres       None
# 12              public                      utq   postgres       None
# 13              public                      utb   postgres       None
# 14              public                      utv   postgres       None
# 15          pg_catalog             pg_statistic   postgres       None
# 16              public                  classes   postgres       None
# 17              public                    ships   postgres       None
# 18              public                  battles   postgres       None
# 19              public                 outcomes   postgres       None
# 20              public              winequality   postgres       None
# 21          pg_catalog         pg_foreign_table   postgres       None
# 22          pg_catalog                pg_authid   postgres  pg_global
# 23          pg_catalog          pg_user_mapping   postgres       None
# 24          pg_catalog          pg_subscription   postgres  pg_global
# 25          pg_catalog           pg_largeobject   postgres       None
# 26          pg_catalog                  pg_type   postgres       None
# 27          pg_catalog             pg_attribute   postgres       None
# 28          pg_catalog                  pg_proc   postgres       None
# 29          pg_catalog                 pg_class   postgres       None
# 30          pg_catalog               pg_attrdef   postgres       None
# 31          pg_catalog            pg_constraint   postgres       None
# 32          pg_catalog              pg_inherits   postgres       None
# 33          pg_catalog                 pg_index   postgres       None
# 34          pg_catalog              pg_operator   postgres       None
# 35          pg_catalog              pg_opfamily   postgres       None
# 36          pg_catalog               pg_opclass   postgres       None
# 37          pg_catalog                    pg_am   postgres       None
# 38          pg_catalog                  pg_amop   postgres       None
# 39          pg_catalog                pg_amproc   postgres       None
# 40          pg_catalog              pg_language   postgres       None
# 41          pg_catalog  pg_largeobject_metadata   postgres       None
# 42          pg_catalog             pg_aggregate   postgres       None
# 43          pg_catalog         pg_statistic_ext   postgres       None
# 44          pg_catalog               pg_rewrite   postgres       None
# 45          pg_catalog               pg_trigger   postgres       None
# 46          pg_catalog         pg_event_trigger   postgres       None
# 47          pg_catalog           pg_description   postgres       None
# 48          pg_catalog                  pg_cast   postgres       None
# 49          pg_catalog                  pg_enum   postgres       None
# 50          pg_catalog             pg_namespace   postgres       None
# 51          pg_catalog            pg_conversion   postgres       None
# 52          pg_catalog                pg_depend   postgres       None
# 53          pg_catalog              pg_database   postgres  pg_global
# 54          pg_catalog       pg_db_role_setting   postgres  pg_global
# 55          pg_catalog            pg_tablespace   postgres  pg_global
# 56          pg_catalog            pg_pltemplate   postgres  pg_global
# 57          pg_catalog          pg_auth_members   postgres  pg_global
# 58          pg_catalog              pg_shdepend   postgres  pg_global
# 59          pg_catalog         pg_shdescription   postgres  pg_global
# 60          pg_catalog             pg_ts_config   postgres       None
# 61          pg_catalog         pg_ts_config_map   postgres       None
# 62          pg_catalog               pg_ts_dict   postgres       None
# 63          pg_catalog             pg_ts_parser   postgres       None
# 64          pg_catalog           pg_ts_template   postgres       None
# 65          pg_catalog             pg_extension   postgres       None
# 66          pg_catalog  pg_foreign_data_wrapper   postgres       None
# 67          pg_catalog        pg_foreign_server   postgres       None
# 68          pg_catalog                pg_policy   postgres       None
# 69          pg_catalog    pg_replication_origin   postgres  pg_global
# 70          pg_catalog           pg_default_acl   postgres       None
# 71          pg_catalog            pg_init_privs   postgres       None
# 72          pg_catalog              pg_seclabel   postgres       None
# 73          pg_catalog            pg_shseclabel   postgres  pg_global
# 74          pg_catalog             pg_collation   postgres       None
# 75          pg_catalog     pg_partitioned_table   postgres       None
# 76          pg_catalog                 pg_range   postgres       None
# 77          pg_catalog             pg_transform   postgres       None
# 78          pg_catalog              pg_sequence   postgres       None
# 79          pg_catalog           pg_publication   postgres       None
# 80          pg_catalog       pg_publication_rel   postgres       None
# 81          pg_catalog      pg_subscription_rel   postgres       None
# 82  information_schema             sql_features   postgres       None
# 83  information_schema  sql_implementation_info   postgres       None
# 84  information_schema            sql_languages   postgres       None
# 85  information_schema             sql_packages   postgres       None
# 86  information_schema                sql_parts   postgres       None
# 87  information_schema               sql_sizing   postgres       None
# 88  information_schema      sql_sizing_profiles   postgres       None
#
#     hasindexes  hasrules  hastriggers  rowsecurity
# 0         True     False         True        False
# 1         True     False         True        False
# 2         True     False         True        False
# 3         True     False         True        False
# 4         True     False         True        False
# 5         True     False         True        False
# 6         True     False         True        False
# 7         True     False         True        False
# 8         True     False        False        False
# 9         True     False        False        False
# 10        True     False        False        False
# 11        True     False        False        False
# 12        True     False         True        False
# 13        True     False         True        False
# 14        True     False         True        False
# 15        True     False        False        False
# 16        True     False         True        False
# 17        True     False         True        False
# 18        True     False         True        False
# 19        True     False         True        False
# 20        True     False        False        False
# 21        True     False        False        False
# 22        True     False        False        False
# 23        True     False        False        False
# 24        True     False        False        False
# 25        True     False        False        False
# 26        True     False        False        False
# 27        True     False        False        False
# 28        True     False        False        False
# 29        True     False        False        False
# 30        True     False        False        False
# 31        True     False        False        False
# 32        True     False        False        False
# 33        True     False        False        False
# 34        True     False        False        False
# 35        True     False        False        False
# 36        True     False        False        False
# 37        True     False        False        False
# 38        True     False        False        False
# 39        True     False        False        False
# 40        True     False        False        False
# 41        True     False        False        False
# 42        True     False        False        False
# 43        True     False        False        False
# 44        True     False        False        False
# 45        True     False        False        False
# 46        True     False        False        False
# 47        True     False        False        False
# 48        True     False        False        False
# 49        True     False        False        False
# 50        True     False        False        False
# 51        True     False        False        False
# 52        True     False        False        False
# 53        True     False        False        False
# 54        True     False        False        False
# 55        True     False        False        False
# 56        True     False        False        False
# 57        True     False        False        False
# 58        True     False        False        False
# 59        True     False        False        False
# 60        True     False        False        False
# 61        True     False        False        False
# 62        True     False        False        False
# 63        True     False        False        False
# 64        True     False        False        False
# 65        True     False        False        False
# 66        True     False        False        False
# 67        True     False        False        False
# 68        True     False        False        False
# 69        True     False        False        False
# 70        True     False        False        False
# 71        True     False        False        False
# 72        True     False        False        False
# 73        True     False        False        False
# 74        True     False        False        False
# 75        True     False        False        False
# 76        True     False        False        False
# 77        True     False        False        False
# 78        True     False        False        False
# 79        True     False        False        False
# 80        True     False        False        False
# 81        True     False        False        False
# 82       False     False        False        False
# 83       False     False        False        False
# 84       False     False        False        False
# 85       False     False        False        False
# 86       False     False        False        False
# 87       False     False        False        False
# 88       False     False        False        False
