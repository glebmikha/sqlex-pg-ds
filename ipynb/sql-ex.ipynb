# %%
import pandas as pd
import psycopg2

con = psycopg2.connect(host='this_postgres', user='postgres',database='postgres')

con.autocommit = True

def select(sql):
    return pd.read_sql(sql,con)

# %% [markdown]
# List all tables

# %%
sql = '''SELECT * FROM pg_catalog.pg_tables t
where t.schemaname = 'public'
'''

# %%
select(sql)
# Out:
#    schemaname     tablename tableowner tablespace  hasindexes  hasrules  \
# 0      public     passenger   postgres       None        True     False
# 1      public  pass_in_trip   postgres       None        True     False
# 2      public          trip   postgres       None        True     False
# 3      public       company   postgres       None        True     False
# 4      public       product   postgres       None        True     False
# 5      public        laptop   postgres       None        True     False
# 6      public            pc   postgres       None        True     False
# 7      public       printer   postgres       None        True     False
# 8      public        income   postgres       None        True     False
# 9      public       outcome   postgres       None        True     False
# 10     public      income_o   postgres       None        True     False
# 11     public     outcome_o   postgres       None        True     False
# 12     public           utq   postgres       None        True     False
# 13     public           utb   postgres       None        True     False
# 14     public           utv   postgres       None        True     False
# 15     public       classes   postgres       None        True     False
# 16     public         ships   postgres       None        True     False
# 17     public       battles   postgres       None        True     False
# 18     public      outcomes   postgres       None        True     False
#
#     hastriggers  rowsecurity
# 0          True        False
# 1          True        False
# 2          True        False
# 3          True        False
# 4          True        False
# 5          True        False
# 6          True        False
# 7          True        False
# 8         False        False
# 9         False        False
# 10        False        False
# 11        False        False
# 12         True        False
# 13         True        False
# 14         True        False
# 15         True        False
# 16         True        False
# 17         True        False
# 18         True        False

# %% [markdown]
# [Exercise 15](http://sql-ex.ru/exercises/index.php?act=learn&LN=15)

# %% [markdown]
# Get hard drive capacities that are identical for two or more PCs.
# Result set: hd.

# %%
sql = '''
select t.hd from pc t
group by t.hd
having count(1) > 1
'''

# %%
select(sql)
# Out:
#      hd
# 0   8.0
# 1  20.0
# 2   5.0
# 3  14.0
# 4  10.0
